# %%
import sys
import os
# Ruta absoluta a tu proyecto principal
ruta_base = "/home/aarriero/Documents/Angela_cmb/four_year/"
# Agregar al sys.path (al inicio para prioridad)
sys.path.insert(0, ruta_base)
print(ruta_base)
# Out:
# /home/aarriero/Documents/Angela_cmb/four_year/

# %%
from sympy import *
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
import math
from sympy import re, im, I, E, symbols

sys.path.append(os.path.join(ruta_base, "general_documents/definitions_files"))
from def_and_clases import RF_components_behavior
from def_and_clases import TMS_results
from def_and_clases import reemplazo_unidad
# Out:
# /home/aarriero/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
####### sympy variables ####
k1,k2,p,k3,k4=symbols('k1,k2,p,k3,k4')
g1,g2,g3,g4,xsky,xload,ysky,yload,g=symbols('g1,g2,g3,g4,xsky,xload,ysky,yload,g')
n1,n2,n3,n4,n=symbols('n1,n2,n3,n4,n')
g1c,g2c,g3c,g4c,xskyc,xloadc,yskyc,yloadc=symbols('g1c,g2c,g3c,g4c,xskyc,xloadc,yskyc,yloadc')
Tn1,Tn2,Tn3,Tn4=symbols('Tn1,Tn2,Tn3,Tn4')
g1Fc,g2Fc,g3Fc,g4Fc=symbols('g1Fc,g2Fc,g3Fc,g4Fc')
k,v1,v2,v3,v4=symbols('k,v1,v2,v3,v4')
#b1,b2,b3,b4=symbols('b1,b2,b3,b4')
B1,TnF1,TnF2,TnF3,TnF4=symbols('B1,TnF1,TnF2,TnF3,TnF4')
Isky,Qsky,Usky,Vsky=symbols('Isky,Qsky,Usky,Vsky')
Iload,Qload,Uload,Vload=symbols('Iload,Qload,Uload,Vload')
theta_os1,theta_os2,theta_os3=symbols('theta_os1,theta_os2,theta_os3', real=True)
theta_ol1,theta_ol2,theta_ol3=symbols('theta_ol1,theta_ol2,theta_ol3', real=True)
beta_h11_1,beta_h11_2,beta_h11_3=symbols('beta_h11_1,beta_h11_2,beta_h11_3', real=True)
beta_h12_1,beta_h12_2,beta_h12_3=symbols('beta_h12_1,beta_h12_2,beta_h12_3', real=True)
theta_lna3_4,theta_lna1_2=symbols('theta_lna3_4,theta_lna1_2', real=True)
Osx,Osy,Osa,Olx,Oly,Ola=symbols('Osx,Osy,Osa,Olx,Oly,Ola')
### omt sky
lmd_os1,lmd_os2,e_os,phi_os1,phi_os2,phi_os3=symbols('lambda_os1,lambda_os2,epsilon_os,phi_os1,phi_os2,phi_os3')
phi_os1c,phi_os2c,phi_os3c=symbols('phi_os1c,phi_os2c,phi_os3c')
### omt load
lmd_ol1,lmd_ol2,e_ol,phi_ol1,phi_ol2,phi_ol3=symbols('lambda_ol1,lambda_ol2,epsilon_ol,phi_ol1,phi_ol2,phi_ol3')
phi_ol1c,phi_ol2c,phi_ol3c=symbols('phi_ol1c,phi_ol2c,phi_ol3c')
### HYB 11
lmd_h11_1,lmd_h11_4,e_h11,phi_h11_1,phi_h11_2,phi_h11_3=symbols('lambda_h11_1,lambda_h11_4,epsilon_h11,phi_h11_1,phi_h11_2,phi_h11_3')
phi_h11_1c,phi_h11_2c,phi_h11_3c,phi_h11_4c=symbols('phi_h11_1c,phi_h11_2c,phi_h11_3c,phi_h11_4c')
### HYB 12
lmd_h12_1,lmd_h12_4,e_h12,phi_h12_1,phi_h12_2,phi_h12_3=symbols('lambda_h12_1,lambda_h12_4,epsilon_h12,phi_h12_1,phi_h12_2,phi_h12_3')
phi_h12_1c,phi_h12_2c,phi_h12_3c,phi_h12_4c=symbols('phi_h12_1c,phi_h12_2c,phi_h12_3c,phi_h12_4c')
##### lna
spi_lna1_2,spi_lna3_4,phi_lna1_2,phi_lna3_4=symbols('spi_lna1_2,spi_lna3_4,phi_lna1_2,phi_lna3_4')
phi_lna1_2c,phi_lna3_4c=symbols('phi_lna1_2c,phi_lna3_4c')
###### BEM
g1F,g2F,g3F,g4F,n1F,n2F,n3F,n4F,Tn1F,Tn2F,Tn3F,Tn4F=symbols('g1F,g2F,g3F,g4F,n1F,n2F,n3F,n4F,Tn1F,Tn2F,Tn3F,Tn4F')
### LO+MIXER
g1LO,g2LO,g3LO,g4LO,n1M,n2M,n3M,n4M,Tn1M,Tn2M,Tn3M,Tn4M=symbols('g1LO,g2LO,g3LO,g4LO,n1M,n2M,n3M,n4M,Tn1M,Tn2M,Tn3M,Tn4M')
g1M,g2M,g3M,g4M=symbols('g1M,g2M,g3M,g4M')
#### DOWN-CONVERTER
g1DC,g2DC,g3DC,g4DC,n1DC,n2DC,n3DC,n4DC,Tn1DC,Tn2DC,Tn3DC,Tn4DC=symbols('g1DC,g2DC,g3DC,g4DC,n1DC,n2DC,n3DC,n4DC,Tn1DC,Tn2DC,Tn3DC,Tn4DC')

########
print('######### In this code we simulate 6 cases:')
print('### A) IDEAL CASE, B) Attenuation in window and IR filter')
print('### C) lossy OMTs, D) lossy hybrids')
print('### E) lossy LNAs, F) lossy BEM')

print('##################################################################################################################')
# Out:
# ######### In this code we simulate 6 cases:
# ### A) IDEAL CASE, B) Attenuation in window and IR filter
# ### C) lossy OMTs, D) lossy hybrids
# ### E) lossy LNAs, F) lossy BEM
# ##################################################################################################################

# %%
print('######################## IDEAL CASE ######################')
### OPTICAL COMPONENTS
signal_W=np.array([[(1),(0)],[(0),(1)]])   # MATRIX WINDOW
signal_IRf=np.array([[(1),(0)],[(0),(1)]]) # MATRIX IR filter
att_signal1=np.array([[1,0],[0,1]])
att_signal2=np.array([[1,0],[0,1]])
#### OMT ###########
OMTsky=np.array([[1,0],[0,1]])             # MATRIX OMT SKY
OMTload=np.array([[1,0],[0,1]])            # MATRIX OMT LOAD
######### HYB1 #######
HYB11=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])# MATRIX HYBX
HYB12=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])# MATRIX HYBY
###### LNA ######
LNA11=np.array([[1,0],[0,1]])               # MATRIX LNA1 Y LNA2
LNA12=np.array([[1,0],[0,1]])               # MATRIX LNA3 Y LNA4
n1_2=np.array([[0],[0]])                   # MATRIX NOISE 1 Y NOISE 2
n3_4=np.array([[0],[0]])                   # MATRIX NOISE 3 Y NOISE 4

##### BEM
BEM1_2=np.array([[1,0],[0,1]])            # MATRIX BEM amplifier1 AND amplifier2 
BEM3_4=np.array([[1,0],[0,1]])            # MATRIX BEM amplifier3 AND amplifier4 
n1_2F=np.array([[0],[0]])                # MATRIX BEM noise1 AND noise2 
n3_4F=np.array([[0],[0]])                # MATRIX BEM noise3 AND noise4 

### this fuction returns values A1,A2,B1,B2 and then C1,C2,D1,D2 (SECOND HYBRID)
A_C1_tot,A_C2_tot,A_D1_tot,A_D2_tot,A_A1_2,A_B1_2= RF_components_behavior(signal_W,signal_IRf,OMTsky,OMTload,HYB11,HYB12,LNA11,LNA12,n1_2,n3_4,att_signal1,att_signal2,BEM1_2,BEM3_4,n1_2F,n3_4F)

print("A1:",A_A1_2[0])
print("A2:",A_A1_2[1])
print("B1:",A_B1_2[0])
print("B2:",A_B1_2[1])

print("C1",A_C1_tot)
print("C2",A_C2_tot)
print("D1",A_D1_tot)
print("D2",A_D2_tot)

###### THE VALUES C1,C2,D1,D2 squared and set into the stokes parameters

A_O1,A_O2,A_O3,A_O4,A_O5,A_O6,A_O7,A_O8=TMS_results(A_C1_tot,A_C2_tot,A_D1_tot,A_D2_tot)
print("SALIDAS FPGA")
print(simplify(A_O1))
print(simplify(A_O2))
print(simplify(A_O3))
print(simplify(A_O4))
print(simplify(A_O5))
print(simplify(A_O6))
print(simplify(A_O7))
print(simplify(A_O8))
# Out:
# ######################## IDEAL CASE ######################
# A1: [0.707106781186547*xload + 0.707106781186547*xsky]
# A2: [-0.707106781186547*xload + 0.707106781186547*xsky]
# B1: [0.707106781186547*yload + 0.707106781186547*ysky]
# B2: [-0.707106781186547*yload + 0.707106781186547*ysky]
# C1 [1.0*xsky]
# C2 [1.0*xload]
# D1 [1.0*ysky]
# D2 [1.0*yload]
# SALIDAS FPGA
# Matrix([[1.0*Isky]])
# Matrix([[1.0*Qsky]])
# Matrix([[1.0*Usky]])
# Matrix([[1.0*Vsky]])
# Matrix([[1.0*Iload]])
# Matrix([[1.0*Qload]])
# Matrix([[1.0*Uload]])
# Matrix([[1.0*Vload]])

# %%
###############################################################################################################################
print('######################## ATTENUATION OPTICAL COMPONENTS (WINDOW AND IRfilter) ######################')
###############################################################################################################################

### OPTICAL COMPONENTS
signal_W=np.array([[(1),(0)],[(0),(1)]])
signal_IRf=np.array([[(1),(0)],[(0),(1)]])
att_signal1=np.array([[k1,0],[0,k2*phi_lna1_2]]) ## attenuation k1(x) and k2(y)
att_signal2=np.array([[k3,0],[0,k4*phi_lna3_4]]) ## attenuation k1(x) and k2(y)
#### OMT ########### IDEAL CASE
OMTsky=np.array([[1,0],[0,1]])
OMTload=np.array([[1,0],[0,1]])
######### HYB1 ####### IDEAL CASE
HYB11=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])
HYB12=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])
###### LNA ###### IDEAL CASE
LNA11=np.array([[1,0],[0,1]])
LNA12=np.array([[1,0],[0,1]])
n1_2=np.array([[0],[0]])
n3_4=np.array([[0],[0]])

##### BEM IDEAL CASE
BEM1_2=np.array([[1,0],[0,1]])
BEM3_4=np.array([[1,0],[0,1]])
n1_2F=np.array([[0],[0]])
n3_4F=np.array([[0],[0]])

B_C1_tot,B_C2_tot,B_D1_tot,B_D2_tot,B_A1_2,B_B1_2= RF_components_behavior(signal_W,signal_IRf,OMTsky,OMTload,HYB11,HYB12,LNA11,LNA12,n1_2,n3_4,att_signal1,att_signal2,BEM1_2,BEM3_4,n1_2F,n3_4F)

B_O1,B_O2,B_O3,B_O4,B_O5,B_O6,B_O7,B_O8=TMS_results(B_C1_tot,B_C2_tot,B_D1_tot,B_D2_tot)

B_O1_order=collect(expand(B_O1[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
B_O2_order=collect(expand(B_O2[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
B_O3_order=collect(expand(B_O3[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
B_O4_order=collect(expand(B_O4[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
B_O5_order=collect(expand(B_O5[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
B_O6_order=collect(expand(B_O6[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
B_O7_order=collect(expand(B_O7[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
B_O8_order=collect(expand(B_O8[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))

#print(B_C1_tot)
#print(B_C2_tot)
#print(B_D1_tot)
#print(B_D2_tot)

print(simplify(B_O1_order)) #I1
print(simplify(B_O2_order)) #Q2
print(simplify(B_O5_order)) #I2
print(simplify(B_O3_order)) #U1
print(simplify(B_O4_order)) #V1
print(simplify(B_O6_order)) #Q2
print(simplify(B_O7_order)) #U2
print(simplify(B_O8_order)) #V2
# Out:
# ######################## ATTENUATION OPTICAL COMPONENTS (WINDOW AND IRfilter) ######################
# 0.5*Isky*(k1**2*k3**2 + k2**2*k4**2) - 0.5*Qsky*(-k1**2*k3**2 + k2**2*k4**2)
# 0.5*Isky*(k1**2*k3**2 - k2**2*k4**2) + 0.5*Qsky*(k1**2*k3**2 + k2**2*k4**2)
# 1.0*Iload
# 1.0*k1*k2*k3*k4*(Usky*cos(theta_lna1_2 + theta_lna3_4) + Vsky*sin(theta_lna1_2 + theta_lna3_4))
# 1.0*k1*k2*k3*k4*(-Usky*sin(theta_lna1_2 + theta_lna3_4) + Vsky*cos(theta_lna1_2 + theta_lna3_4))
# 1.0*Qload
# 1.0*Uload
# 1.0*Vload

# %%
###############################################################################################################################
print('######################## NON-IDEAL OMT ######################')
###############################################################################################################################

### OPTICAL COMPONENTS
signal_W=np.array([[(1),(0)],[(0),(1)]])
signal_IRf=np.array([[(1),(0)],[(0),(1)]])
#att_signal=np.array([[k,0],[0,k]])
att_signal1=np.array([[1,0],[0,1]])
att_signal2=np.array([[1,0],[0,1]])
#### OMT ###########
#OMTsky=np.array([[sqrt(lmd_os1-e_os),sqrt(e_os)*phi_os1],[sqrt(e_os)*phi_os2,sqrt(lmd_os2-e_os)*phi_os3]])
#OMTload=np.array([[sqrt(lmd_ol1-e_ol),sqrt(e_ol)*phi_ol1],[sqrt(e_ol)*phi_ol2,sqrt(lmd_ol2-e_ol)*phi_ol3]])
############################
OMTsky=np.array([[(1+lmd_os1),(e_os)*phi_os1],[(e_os)*phi_os2,(1+lmd_os2)*phi_os3]])
OMTload=np.array([[(1+lmd_ol1),(e_ol)*phi_ol1],[(e_ol)*phi_ol2,(1+lmd_ol2)*phi_ol3]])
######### HYB1 #######
HYB11=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])
HYB12=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])
###### LNA ######
LNA11=np.array([[1,0],[0,1]])
LNA12=np.array([[1,0],[0,1]])
n1_2=np.array([[0],[0]])
n3_4=np.array([[0],[0]])
##### BEM
BEM1_2=np.array([[1,0],[0,1]])
BEM3_4=np.array([[1,0],[0,1]])
n1_2B=np.array([[0],[0]])
n3_4B=np.array([[0],[0]])

D_C1_tot,D_C2_tot,D_D1_tot,D_D2_tot,D_A1_2,D_B1_2= RF_components_behavior(signal_W,signal_IRf,OMTsky,OMTload,HYB11,HYB12,LNA11,LNA12,n1_2,n3_4,att_signal1,att_signal2,BEM1_2,BEM3_4,n1_2F,n3_4F)

D_O1,D_O2,D_O3,D_O4,D_O5,D_O6,D_O7,D_O8=TMS_results(D_C1_tot,D_C2_tot,D_D1_tot,D_D2_tot)

D_O1_order=collect(expand(D_O1[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
D_O2_order=collect(expand(D_O2[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O3_order=collect(expand(D_O3[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O4_order=collect(expand(D_O4[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
D_O5_order=collect(expand(D_O5[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O6_order=collect(expand(D_O6[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O7_order=collect(expand(D_O7[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O8_order=collect(expand(D_O8[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
print('simplify:')
#print(simplify(D_O1_order))
#print(simplify(D_O2_order))
#print(simplify(D_O5_order))
# Out:
# ######################## NON-IDEAL OMT ######################
# simplify:

# %%
###############################################################################################################################
print('######################## NON-IDEAL HYB ######################')
###############################################################################################################################

### OPTICAL COMPONENTS
signal_W=np.array([[(1),(0)],[(0),(1)]])
signal_IRf=np.array([[(1),(0)],[(0),(1)]])
#att_signal=np.array([[k,0],[0,k]])
att_signal1=np.array([[1,0],[0,1]])
att_signal2=np.array([[1,0],[0,1]])
#### OMT ###########
OMTsky=np.array([[1,0],[0,1]])
OMTload=np.array([[1,0],[0,1]])

######################################################################
lmd_h11_1=0
lmd_h11_4=0
lmd_h12_1=0
lmd_h12_4=0
e_h11=0
e_h12=0
######### HYB1 #######
HYB11=(1/np.sqrt(2))*np.array([[(1+lmd_h11_1),phi_os1*(1+e_h11)],
 [phi_os2*(1+e_h11),-phi_os3*(1+lmd_h11_4)]])

HYB12=(1/np.sqrt(2))*np.array([[(1+lmd_h12_1),phi_ol1*(1+e_h12)],
 [phi_ol2*(1+e_h12),-phi_ol3*(1+lmd_h12_4)]])
######################################################################

######### HYB1 ####### estos angulos hay algo mal, uso los del omt para ejecutar el codigo
#HYB11=(1/np.sqrt(2))*np.array([[(1+lmd_h11_1),phi_h11_3*(1+e_h11)],
# [phi_h11_1*(1+e_h11),-phi_h11_2*(1+lmd_h11_4)]])

#HYB12=(1/np.sqrt(2))*np.array([[(1+lmd_h12_1),phi_h12_3*(1+e_h12)],
# [phi_h12_1*(1+e_h12),-phi_h12_2*(1+lmd_h12_4)]])
######################################################################


###### LNA ######
LNA11=np.array([[1,0],[0,1]])
LNA12=np.array([[1,0],[0,1]])
n1_2=np.array([[0],[0]])
n3_4=np.array([[0],[0]])

##### BEM
BEM1_2=np.array([[1,0],[0,1]])
BEM3_4=np.array([[1,0],[0,1]])
n1_2F=np.array([[0],[0]])
n3_4F=np.array([[0],[0]])

D_C1_tot,D_C2_tot,D_D1_tot,D_D2_tot,D_A1_2,D_B1_2= RF_components_behavior(signal_W,signal_IRf,OMTsky,OMTload,HYB11,HYB12,LNA11,LNA12,n1_2,n3_4,att_signal1,att_signal2,BEM1_2,BEM3_4,n1_2F,n3_4F)

D_O1,D_O2,D_O3,D_O4,D_O5,D_O6,D_O7,D_O8=TMS_results(D_C1_tot,D_C2_tot,D_D1_tot,D_D2_tot)

D_O1_order=collect(expand(D_O1[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
D_O2_order=collect(expand(D_O2[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O3_order=collect(expand(D_O3[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O4_order=collect(expand(D_O4[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
D_O5_order=collect(expand(D_O5[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O6_order=collect(expand(D_O6[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O7_order=collect(expand(D_O7[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
#D_O8_order=collect(expand(D_O8[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
print('simplify:')
#print(simplify(D_O1_order))
#print(simplify(D_O2_order))
#print(simplify(D_O5_order))
# Out:
# ######################## NON-IDEAL HYB ######################
# simplify:

# %%
print(D_O1_order)
# Out:
# Iload*(0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 + 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 + 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 - 0.25*sin(theta_ol3)**2*cos(theta_ol2) + 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 - 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 + 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 - 0.25*cos(theta_ol2)*cos(theta_ol3)**2 + 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 - 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2) + Isky*(0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 + 0.125*cos(theta_ol2)**2 + 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 + 0.25*cos(theta_os2) + 0.25) + Qload*(-0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 - 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 - 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 + 0.25*sin(theta_ol3)**2*cos(theta_ol2) - 0.125*sin(theta_ol3)**2 + 0.125*
# ...

# %%
simplify(Iload*(0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 + 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 + 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 - 0.25*sin(theta_ol3)**2*cos(theta_ol2) + 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 - 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 + 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 - 0.25*cos(theta_ol2)*cos(theta_ol3)**2 + 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 - 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2) )
# Out:
# Iload⋅(-0.25⋅cos(θₒₗ₂) - 0.25⋅cos(θₒₛ₂) + 0.5)

# %%
simplify(+ Isky*(0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 + 0.125*cos(theta_ol2)**2 + 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 + 0.25*cos(theta_os2) + 0.25))
# Out:
# Isky⋅(0.25⋅cos(θₒₗ₂) + 0.25⋅cos(θₒₛ₂) + 0.5)

# %%
simplify( + Qload*(-0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 - 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 - 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 + 0.25*sin(theta_ol3)**2*cos(theta_ol2) - 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 - 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 - 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 + 0.25*cos(theta_ol2)*cos(theta_ol3)**2 - 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 - 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2))
# Out:
# 0.25⋅Qload⋅(cos(θₒₗ₂) - cos(θₒₛ₂))

# %%
simplify( + Qsky*(-0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 - 0.125*cos(theta_ol2)**2 - 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 + 0.25*cos(theta_os2)))
# Out:
# 0.25⋅Qsky⋅(-cos(θₒₗ₂) + cos(θₒₛ₂))

# %%
print(D_O2_order)
# Out:
# Iload*(-0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 - 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 - 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 + 0.25*sin(theta_ol3)**2*cos(theta_ol2) - 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 - 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 - 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 + 0.25*cos(theta_ol2)*cos(theta_ol3)**2 - 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 - 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2) + Isky*(-0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 - 0.125*cos(theta_ol2)**2 - 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 + 0.25*cos(theta_os2)) + Qload*(0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 + 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 + 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 - 0.25*sin(theta_ol3)**2*cos(theta_ol2) + 0.125*sin(theta_ol3)**2 + 0.125*sin(th
# ...

# %%
simplify(Iload*(-0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 - 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 - 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 + 0.25*sin(theta_ol3)**2*cos(theta_ol2) - 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 - 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 - 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 + 0.25*cos(theta_ol2)*cos(theta_ol3)**2 - 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 - 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2))
# Out:
# 0.25⋅Iload⋅(cos(θₒₗ₂) - cos(θₒₛ₂))

# %%
simplify( + Isky*(-0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 - 0.125*cos(theta_ol2)**2 - 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 + 0.25*cos(theta_os2)))
# Out:
# 0.25⋅Isky⋅(-cos(θₒₗ₂) + cos(θₒₛ₂))

# %%
simplify( + Qload*(0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 + 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 + 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 - 0.25*sin(theta_ol3)**2*cos(theta_ol2) + 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 - 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 + 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 - 0.25*cos(theta_ol2)*cos(theta_ol3)**2 + 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 - 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2) )
# Out:
# Qload⋅(-0.25⋅cos(θₒₗ₂) - 0.25⋅cos(θₒₛ₂) + 0.5)

# %%
simplify(+ Qsky*(0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 + 0.125*cos(theta_ol2)**2 + 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 + 0.25*cos(theta_os2) + 0.25))
# Out:
# Qsky⋅(0.25⋅cos(θₒₗ₂) + 0.25⋅cos(θₒₛ₂) + 0.5)

# %%
print(D_O5_order)
# Out:
# Iload*(0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 + 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 + 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 + 0.25*sin(theta_ol3)**2*cos(theta_ol2) + 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 + 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 + 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 + 0.25*cos(theta_ol2)*cos(theta_ol3)**2 + 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 + 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2) + Isky*(0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 + 0.125*cos(theta_ol2)**2 - 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 - 0.25*cos(theta_os2) + 0.25) + Qload*(-0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 - 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 - 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 - 0.25*sin(theta_ol3)**2*cos(theta_ol2) - 0.125*sin(theta_ol3)**2 + 0.125*
# ...

# %%
simplify(Iload*(0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 + 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 + 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 + 0.25*sin(theta_ol3)**2*cos(theta_ol2) + 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 + 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 + 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 + 0.25*cos(theta_ol2)*cos(theta_ol3)**2 + 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 + 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2))
# Out:
# Iload⋅(0.25⋅cos(θₒₗ₂) + 0.25⋅cos(θₒₛ₂) + 0.5)

# %%
simplify( + Isky*(0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 + 0.125*cos(theta_ol2)**2 - 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 - 0.25*cos(theta_os2) + 0.25) )
# Out:
# Isky⋅(-0.25⋅cos(θₒₗ₂) - 0.25⋅cos(θₒₛ₂) + 0.5)

# %%
simplify(+ Qload*(-0.125*sin(theta_ol2)**2*sin(theta_ol3)**2 - 0.125*sin(theta_ol2)**2*cos(theta_ol3)**2 - 0.125*sin(theta_ol3)**2*cos(theta_ol2)**2 - 0.25*sin(theta_ol3)**2*cos(theta_ol2) - 0.125*sin(theta_ol3)**2 + 0.125*sin(theta_os2)**2*sin(theta_os3)**2 + 0.125*sin(theta_os2)**2*cos(theta_os3)**2 + 0.125*sin(theta_os3)**2*cos(theta_os2)**2 + 0.25*sin(theta_os3)**2*cos(theta_os2) + 0.125*sin(theta_os3)**2 - 0.125*cos(theta_ol2)**2*cos(theta_ol3)**2 - 0.25*cos(theta_ol2)*cos(theta_ol3)**2 - 0.125*cos(theta_ol3)**2 + 0.125*cos(theta_os2)**2*cos(theta_os3)**2 + 0.25*cos(theta_os2)*cos(theta_os3)**2 + 0.125*cos(theta_os3)**2) )
# Out:
# 0.25⋅Qload⋅(-cos(θₒₗ₂) + cos(θₒₛ₂))

# %%
simplify(+ Qsky*(-0.125*sin(theta_ol2)**2 + 0.125*sin(theta_os2)**2 - 0.125*cos(theta_ol2)**2 + 0.25*cos(theta_ol2) + 0.125*cos(theta_os2)**2 - 0.25*cos(theta_os2)))
# Out:
# 0.25⋅Qsky⋅(cos(θₒₗ₂) - cos(θₒₛ₂))

# %%
###############################################################################################################################
print('######################## NON-IDEAL LNA ######################')
###############################################################################################################################

### OPTICAL COMPONENTS
signal_W=np.array([[(1),(0)],[(0),(1)]])
signal_IRf=np.array([[(1),(0)],[(0),(1)]])
att_signal1=np.array([[1,0],[0,1]])
att_signal2=np.array([[1,0],[0,1]])
#### OMT ###########
OMTsky=np.array([[1,0],[0,1]])
OMTload=np.array([[1,0],[0,1]])
######### HYB1 #######
HYB11=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])
HYB12=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])

###### LNA ######
#g1=1;g2=1;g3=1;g4=1
#LNA1_2=np.array([[g1,0],[0,g2*phi_lna1_2]])
#LNA3_4=np.array([[g3,0],[0,g4*phi_lna3_4]])
#g2=g1;g3=g1;g4=g1

LNA1_2=np.array([[g1,0],[0,g2]])
LNA3_4=np.array([[g3,0],[0,g4]])
n1_2=np.array([[n1],[n2]])
n3_4=np.array([[n3],[n4]])
#n2=n1;n3=n1;n4=n1
#n1_2=np.array([[0],[0]])
#n3_4=np.array([[0],[0]])

##### BEM
BEM1_2=np.array([[1,0],[0,1]])
BEM3_4=np.array([[1,0],[0,1]])
n1_2F=np.array([[0],[0]])
n3_4F=np.array([[0],[0]])

F_C1_tot,F_C2_tot,F_D1_tot,F_D2_tot,F_A1_2,F_B1_2= RF_components_behavior(signal_W,signal_IRf,OMTsky,OMTload,HYB11,HYB12,LNA1_2,LNA3_4,n1_2,n3_4,att_signal1,att_signal2,BEM1_2,BEM3_4,n1_2F,n3_4F)

F_O1,F_O2,F_O3,F_O4,F_O5,F_O6,F_O7,F_O8=TMS_results(F_C1_tot,F_C2_tot,F_D1_tot,F_D2_tot)

F_O1_order=collect(expand(F_O1[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O2_order=collect(expand(F_O2[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O3_order=collect(expand(F_O3[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O4_order=collect(expand(F_O4[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O5_order=collect(expand(F_O5[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O6_order=collect(expand(F_O6[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O7_order=collect(expand(F_O7[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O8_order=collect(expand(F_O8[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))

print('simplify:')
#print(simplify(F_O1_order))
#print(simplify(F_O2_order))
#print(simplify(F_O5_order))
# Out:
# ######################## NON-IDEAL LNA ######################
# simplify:

# %%
###############################################################################################################################
print('######################## NON-IDEAL BEM  ######################')
###############################################################################################################################

### OPTICAL COMPONENTS
signal_W=np.array([[(1),(0)],[(0),(1)]])
signal_IRf=np.array([[(1),(0)],[(0),(1)]])
att_signal1=np.array([[1,0],[0,1]])
att_signal2=np.array([[1,0],[0,1]])
#### OMT ###########
OMTsky=np.array([[1,0],[0,1]])
OMTload=np.array([[1,0],[0,1]])
######### HYB1 #######
HYB11=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])
HYB12=(1/np.sqrt(2))*np.array([[1,1],[1,-1]])
###### LNA ######
LNA1_2=np.array([[g1,0],[0,g2*phi_lna1_2]])
LNA3_4=np.array([[g3,0],[0,g4*phi_lna3_4]])
n1_2=np.array([[n1],[n2]])
n3_4=np.array([[n3],[n4]])

##### BEM
#g2F=g1F;g3F=g1F;g4F=g1F
#n2F=n1F;n3F=n1F;n4F=n1F
BEM1_2=np.array([[g1F,0],[0,g2F*phi_h11_1]])
BEM3_4=np.array([[g3F,0],[0,g4F*phi_h11_2]])
n1_2F=np.array([[n1F],[n2F]])
n3_4F=np.array([[n3F],[n4F]])

F_C1_tot,F_C2_tot,F_D1_tot,F_D2_tot,F_A1_2,F_B1_2= RF_components_behavior(signal_W,signal_IRf,OMTsky,OMTload,HYB11,HYB12,LNA1_2,LNA3_4,n1_2,n3_4,att_signal1,att_signal2,BEM1_2,BEM3_4,n1_2F,n3_4F)

F_O1,F_O2,F_O3,F_O4,F_O5,F_O6,F_O7,F_O8=TMS_results(F_C1_tot,F_C2_tot,F_D1_tot,F_D2_tot)

F_O1_order=collect(expand(F_O1[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O2_order=collect(expand(F_O2[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O3_order=collect(expand(F_O3[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O4_order=collect(expand(F_O4[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O5_order=collect(expand(F_O5[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O6_order=collect(expand(F_O6[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O7_order=collect(expand(F_O7[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))
F_O8_order=collect(expand(F_O8[0]),(xsky,xload,ysky,yload,xskyc,xloadc,yskyc,yloadc,Iload,Isky,Usky,Qsky,Vsky,Qload,Uload,Vload))

print('simplify:')
#print(simplify(F_O1_order))
#print(simplify(F_O2_order))
#print(simplify(F_O5_order))
# Out:
# ######################## NON-IDEAL BEM  ######################
# simplify:

# %%
print(F_O1_order-F_O5_order)

# %%
simplify(-Iload*(0.125*g1**2*g1F**2 - 0.25*g1*g1F*g2*g2F*sin(beta_h11_1)*sin(theta_lna1_2) + 0.25*g1*g1F*g2*g2F*cos(beta_h11_1)*cos(theta_lna1_2) + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*sin(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(theta_lna1_2)**2*cos(beta_h11_1)**2 + 0.125*g2**2*g2F**2*cos(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g3**2*g3F**2 - 0.25*g3*g3F*g4*g4F*sin(beta_h11_2)*sin(theta_lna3_4) + 0.25*g3*g3F*g4*g4F*cos(beta_h11_2)*cos(theta_lna3_4) + 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*sin(theta_lna3_4)**2 + 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*cos(theta_lna3_4)**2 + 0.125*g4**2*g4F**2*sin(theta_lna3_4)**2*cos(beta_h11_2)**2 + 0.125*g4**2*g4F**2*cos(beta_h11_2)**2*cos(theta_lna3_4)**2) + Iload*(0.125*g1**2*g1F**2 + 0.25*g1*g1F*g2*g2F*sin(beta_h11_1)*sin(theta_lna1_2) - 0.25*g1*g1F*g2*g2F*cos(beta_h11_1)*cos(theta_lna1_2) + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*sin(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(theta_lna1_2)**2*cos(beta_h11_1)**2 + 0.125*g2**2*g2F**2*cos(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g3**2*g3F**2 + 0.25*g3*g3F*g4*g4F*sin(beta_h11_2)*sin(theta_lna3_4) - 0.25*g3*g3F*g4*g4F*cos(beta_h11_2)*cos(theta_lna3_4) + 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*sin(theta_lna3_4)**2 + 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*cos(theta_lna3_4)**2 + 0.125*g4**2*g4F**2*sin(theta_lna3_4)**2*cos(beta_h11_2)**2 + 0.125*g4**2*g4F**2*cos(beta_h11_2)**2*cos(theta_lna3_4)**2))

# %%
simplify( + Isky*(0.125*g1**2*g1F**2 - 0.25*g1*g1F*g2*g2F*sin(beta_h11_1)*sin(theta_lna1_2) + 0.25*g1*g1F*g2*g2F*cos(beta_h11_1)*cos(theta_lna1_2) + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*sin(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(theta_lna1_2)**2*cos(beta_h11_1)**2 + 0.125*g2**2*g2F**2*cos(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g3**2*g3F**2 - 0.25*g3*g3F*g4*g4F*sin(beta_h11_2)*sin(theta_lna3_4) + 0.25*g3*g3F*g4*g4F*cos(beta_h11_2)*cos(theta_lna3_4) + 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*sin(theta_lna3_4)**2 + 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*cos(theta_lna3_4)**2 + 0.125*g4**2*g4F**2*sin(theta_lna3_4)**2*cos(beta_h11_2)**2 + 0.125*g4**2*g4F**2*cos(beta_h11_2)**2*cos(theta_lna3_4)**2) - Isky*(0.125*g1**2*g1F**2 + 0.25*g1*g1F*g2*g2F*sin(beta_h11_1)*sin(theta_lna1_2) - 0.25*g1*g1F*g2*g2F*cos(beta_h11_1)*cos(theta_lna1_2) + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*sin(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(theta_lna1_2)**2*cos(beta_h11_1)**2 + 0.125*g2**2*g2F**2*cos(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g3**2*g3F**2 + 0.25*g3*g3F*g4*g4F*sin(beta_h11_2)*sin(theta_lna3_4) - 0.25*g3*g3F*g4*g4F*cos(beta_h11_2)*cos(theta_lna3_4) + 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*sin(theta_lna3_4)**2 + 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*cos(theta_lna3_4)**2 + 0.125*g4**2*g4F**2*sin(theta_lna3_4)**2*cos(beta_h11_2)**2 + 0.125*g4**2*g4F**2*cos(beta_h11_2)**2*cos(theta_lna3_4)**2))

# %%
simplify( - Qload*(0.125*g1**2*g1F**2 - 0.25*g1*g1F*g2*g2F*sin(beta_h11_1)*sin(theta_lna1_2) + 0.25*g1*g1F*g2*g2F*cos(beta_h11_1)*cos(theta_lna1_2) + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*sin(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(theta_lna1_2)**2*cos(beta_h11_1)**2 + 0.125*g2**2*g2F**2*cos(beta_h11_1)**2*cos(theta_lna1_2)**2 - 0.125*g3**2*g3F**2 + 0.25*g3*g3F*g4*g4F*sin(beta_h11_2)*sin(theta_lna3_4) - 0.25*g3*g3F*g4*g4F*cos(beta_h11_2)*cos(theta_lna3_4) - 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*sin(theta_lna3_4)**2 - 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*cos(theta_lna3_4)**2 - 0.125*g4**2*g4F**2*sin(theta_lna3_4)**2*cos(beta_h11_2)**2 - 0.125*g4**2*g4F**2*cos(beta_h11_2)**2*cos(theta_lna3_4)**2) + Qload*(0.125*g1**2*g1F**2 + 0.25*g1*g1F*g2*g2F*sin(beta_h11_1)*sin(theta_lna1_2) - 0.25*g1*g1F*g2*g2F*cos(beta_h11_1)*cos(theta_lna1_2) + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*sin(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(theta_lna1_2)**2*cos(beta_h11_1)**2 + 0.125*g2**2*g2F**2*cos(beta_h11_1)**2*cos(theta_lna1_2)**2 - 0.125*g3**2*g3F**2 - 0.25*g3*g3F*g4*g4F*sin(beta_h11_2)*sin(theta_lna3_4) + 0.25*g3*g3F*g4*g4F*cos(beta_h11_2)*cos(theta_lna3_4) - 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*sin(theta_lna3_4)**2 - 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*cos(theta_lna3_4)**2 - 0.125*g4**2*g4F**2*sin(theta_lna3_4)**2*cos(beta_h11_2)**2 - 0.125*g4**2*g4F**2*cos(beta_h11_2)**2*cos(theta_lna3_4)**2))

# %%
simplify( + Qsky*(0.125*g1**2*g1F**2 - 0.25*g1*g1F*g2*g2F*sin(beta_h11_1)*sin(theta_lna1_2) + 0.25*g1*g1F*g2*g2F*cos(beta_h11_1)*cos(theta_lna1_2) + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*sin(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(theta_lna1_2)**2*cos(beta_h11_1)**2 + 0.125*g2**2*g2F**2*cos(beta_h11_1)**2*cos(theta_lna1_2)**2 - 0.125*g3**2*g3F**2 + 0.25*g3*g3F*g4*g4F*sin(beta_h11_2)*sin(theta_lna3_4) - 0.25*g3*g3F*g4*g4F*cos(beta_h11_2)*cos(theta_lna3_4) - 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*sin(theta_lna3_4)**2 - 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*cos(theta_lna3_4)**2 - 0.125*g4**2*g4F**2*sin(theta_lna3_4)**2*cos(beta_h11_2)**2 - 0.125*g4**2*g4F**2*cos(beta_h11_2)**2*cos(theta_lna3_4)**2) - Qsky*(0.125*g1**2*g1F**2 + 0.25*g1*g1F*g2*g2F*sin(beta_h11_1)*sin(theta_lna1_2) - 0.25*g1*g1F*g2*g2F*cos(beta_h11_1)*cos(theta_lna1_2) + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*sin(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(beta_h11_1)**2*cos(theta_lna1_2)**2 + 0.125*g2**2*g2F**2*sin(theta_lna1_2)**2*cos(beta_h11_1)**2 + 0.125*g2**2*g2F**2*cos(beta_h11_1)**2*cos(theta_lna1_2)**2 - 0.125*g3**2*g3F**2 - 0.25*g3*g3F*g4*g4F*sin(beta_h11_2)*sin(theta_lna3_4) + 0.25*g3*g3F*g4*g4F*cos(beta_h11_2)*cos(theta_lna3_4) - 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*sin(theta_lna3_4)**2 - 0.125*g4**2*g4F**2*sin(beta_h11_2)**2*cos(theta_lna3_4)**2 - 0.125*g4**2*g4F**2*sin(theta_lna3_4)**2*cos(beta_h11_2)**2 - 0.125*g4**2*g4F**2*cos(beta_h11_2)**2*cos(theta_lna3_4)**2)
)

# %%
print(simplify(F_O1_order))

# %%
simplify(0.125*Iload*g1**2*g1F**2 - 0.25*Iload*g1*g1F*g2*g2F*cos(beta_h11_1 + theta_lna1_2) + 0.125*Iload*g2**2*g2F**2 + 0.125*Iload*g3**2*g3F**2 - 0.25*Iload*g3*g3F*g4*g4F*cos(beta_h11_2 + theta_lna3_4) + 0.125*Iload*g4**2*g4F**2)

# %%
simplify(0.5*Tn1*g1**2*g1F**2 + 0.5*Tn2*g2**2*g2F**2 + 0.5*Tn3*g3**2*g3F**2 + 0.5*Tn4*g4**2*g4F**2 + 0.5*TnF1*g1F**2 + 0.5*TnF2*g2F**2 + 0.5*TnF3*g3F**2 + 0.5*TnF4*g4F**2
)
